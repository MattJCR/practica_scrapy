# %%
# !pip install ipykernel Scrapy

# %%
print("INICIAMOS EL PROYECTO DE SCRAPY")
# !scrapy startproject imdb ../imdb_scrapy
# Out:
# INICIAMOS EL PROYECTO DE SCRAPY
# New Scrapy project 'imdb', using template directory 'C:\Users\mateo\Desktop\IABD\scrapyApp\lib\site-packages\scrapy\templates\project', created in:
#     c:\Users\mateo\Desktop\IABD\PII\imdb_scrapy
#
# You can start your first spider with:
#     cd ../imdb_scrapy
#     scrapy genspider example example.com

# %%
# !cd ../imdb_scrapy/imdb && scrapy genspider robot https://www.imdb.com
# Out:
# Created spider 'robot' using template 'basic' in module:
#   imdb.spiders.robot

# %%
# !cd ../imdb_scrapy/imdb && del /f result.json && scrapy crawl robot -o result.json
# Out:
# 2022-11-29 17:25:27 [scrapy.utils.log] INFO: Scrapy 2.7.1 started (bot: imdb)
# 2022-11-29 17:25:27 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.12, cssselect 1.2.0, parsel 1.7.0, w3lib 2.0.1, Twisted 22.10.0, Python 3.10.7 (tags/v3.10.7:6cc6b13, Sep  5 2022, 14:08:36) [MSC v.1933 64 bit (AMD64)], pyOpenSSL 22.1.0 (OpenSSL 3.0.7 1 Nov 2022), cryptography 38.0.3, Platform Windows-10-10.0.22621-SP0
# 2022-11-29 17:25:27 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'imdb',
#  'NEWSPIDER_MODULE': 'imdb.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'SPIDER_MODULES': ['imdb.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor',
#  'USER_AGENT': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 '
#                '(KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36'}
# 2022-11-29 17:25:27 [asyncio] DEBUG: Using selector: SelectSelector
# ...
